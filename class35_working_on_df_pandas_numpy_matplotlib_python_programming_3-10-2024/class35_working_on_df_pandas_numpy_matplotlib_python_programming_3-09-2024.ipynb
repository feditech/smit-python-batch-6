# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("dataset.csv")

# %%
data
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
data.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
data.shape
# Out:
# (1000, 10)

# %%
data.Series_Title.value_counts()
# Out:
# Series_Title
# Drishyam                    2
# The Shawshank Redemption    1
# Awakenings                  1
# Tombstone                   1
# The Sandlot                 1
#                            ..
# Guardians of the Galaxy     1
# Blade Runner 2049           1
# Her                         1
# Bohemian Rhapsody           1
# The 39 Steps                1
# Name: count, Length: 999, dtype: int64

# %%
data[data.Released_Year =="PG"]
# Out:
#     Series_Title Released_Year  Runtime      Genre  IMDB_Rating    Director  \
# 966    Apollo 13            PG      140  Adventure          7.6  Ron Howard
#
#          Star1  No_of_Votes        Gross  Metascore
# 966  Tom Hanks       269197  173837933.0       77.0

# %%
data.Released_Year.replace("PG",data.Released_Year.mode()[0],inplace =True)

# %%
data[data.Released_Year =="PG"]
# Out:
# Empty DataFrame
# Columns: [Series_Title, Released_Year, Runtime, Genre, IMDB_Rating, Director, Star1, No_of_Votes, Gross, Metascore]
# Index: []

# %%
data.Released_Year = pd.to_datetime(data.Released_Year)

# %%
data.tail()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 995  Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                   Giant          1956      201   Drama          7.6
# 997   From Here to Eternity          1953      118   Drama          7.6
# 998                Lifeboat          1944       97   Drama          7.6
# 999            The 39 Steps          1935       86   Crime          7.6
#
#              Director              Star1  No_of_Votes        Gross  Metascore
# 995     Blake Edwards     Audrey Hepburn       166544  679874270.0       76.0
# 996    George Stevens   Elizabeth Taylor        34075  195217415.0       84.0
# 997    Fred Zinnemann     Burt Lancaster        43374   30500000.0       85.0
# 998  Alfred Hitchcock  Tallulah Bankhead        26471  852142728.0       78.0
# 999  Alfred Hitchcock       Robert Donat        51853  302787539.0       93.0

# %%
genre = data.Genre.value_counts()
genre
# Out:
# Genre
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.bar(x=genre.index,height=genre.values)
# Out:
# <BarContainer object of 14 artists>

# %%
data.Runtime
# Out:
# 0      142
# 1      175
# 2      152
# 3      202
# 4       96
#       ...
# 995    115
# 996    201
# 997    118
# 998     97
# 999     86
# Name: Runtime, Length: 1000, dtype: int64

# %%
data[data.Runtime >0]
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
data.Metascore.isna().sum()
# Out:
# 157

# %%
data.Metascore.min()
# Out:
# 28.0

# %%
data.Metascore.max()
# Out:
# 100.0

# %%
sns.boxplot(data['Metascore'])

# Add labels
plt.ylabel('Metascore')

# Show the plot
plt.show()

# %%
data[data.Released_Year == "1994"]
# Out:
#                  Series_Title Released_Year  Runtime      Genre  IMDB_Rating  \
# 0    The Shawshank Redemption    1994-01-01      142      Drama          9.3
# 6                Pulp Fiction    1994-01-01      154      Crime          8.9
# 11               Forrest Gump    1994-01-01      142      Drama          8.8
# 42                       Léon    1994-01-01      110     Action          8.5
# 43              The Lion King    1994-01-01       88  Animation          8.5
# 166           Andaz Apna Apna    1994-01-01      160     Action          8.2
# 260     Trois couleurs: Rouge    1994-01-01       99      Drama          8.1
# 261        Chung Hing sam lam    1994-01-01      102     Comedy          8.1
# 519        Once Were Warriors    1994-01-01      102      Crime          7.9
# 657                   Ed Wood    1994-01-01      127  Biography          7.8
# 815                Il postino    1994-01-01      108  Biography          7.7
# ...

# %%
# store all 1994 movies to a new file

movies_1994 = data[data.Released_Year == "1994"]
movies_1994.to_excel("movies_1994.xlsx")

# %%
data[( data.Genre == "Crime") & (data.Metascore >= 90)]
# Out:
#                   Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 1                The Godfather    1972-01-01      175  Crime          9.2
# 3       The Godfather: Part II    1974-01-01      202  Crime          9.0
# 4                 12 Angry Men    1957-01-01       96  Crime          9.0
# 6                 Pulp Fiction    1994-01-01      154  Crime          8.9
# 111                Taxi Driver    1976-01-01      114  Crime          8.3
# 123           Double Indemnity    1944-01-01      107  Crime          8.3
# 162          L.A. Confidential    1997-01-01      138  Crime          8.2
# 186  Du rififi chez les hommes    1955-01-01      118  Crime          8.2
# 189                   Rashômon    1950-01-01       88  Crime          8.2
# 232     No Country for Old Men    2007-01-01      122  Crime          8.1
# 288             Cool Hand Luke    1967-01-01      127  Crime          8.1
# 305          On the Waterfront    1954-01-01      108  Crime          8.1
# ...

# %%
data[( data.Released_Year == "1992") & (data.Genre == "Action")]["Gross"].sum()
# Out:
# 640957295.0

# %%
# total earning of Francis Ford Coppola 
data[( data.Director == "Francis Ford Coppola")]["Gross"].sum()
# Out:
# 346823984.0

# %%
#  total earning of movies whose runtime is greater than 150 , Genre is comedy and IMDB is greater than 8
data[(data.Runtime >= 150) & (data.Genre == "Comedy") & (data.IMDB_Rating >=8) ]["Gross"].sum()
# Out:
# 90885384.0
